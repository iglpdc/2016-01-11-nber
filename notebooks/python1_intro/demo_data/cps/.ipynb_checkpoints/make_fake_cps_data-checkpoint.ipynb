# %%
import os
from subprocess import call

# %%
for y in range(2000,2015):
    y_str = str(y)[-2:]
    newpath = "./data_" + y_str
    print newpath
    if not os.path.exists(newpath): os.makedirs(newpath)
# Out:
# ./data_00
# ./data_01
# ./data_02
# ./data_03
# ./data_04
# ./data_05
# ./data_06
# ./data_07
# ./data_08
# ./data_09
# ./data_10
# ./data_11
# ./data_12
# ./data_13
# ./data_14

# %%
for y in range(2000,2015):
    y_str = str(y)[-2:]
    newpath = "./data_" + y_str
    for m in range(1,13):
        if m < 10:
            mo_str = "0" + str(m)
        else:
            mo_str = str(m)
        f_name = "cpsb" + y_str + mo_str + ".dat"
        to_write = newpath + "/" + f_name
        print to_write
        with open(to_write, 'w') as f:
            f.write("Fake CPS data\n")
# Out:
# ./data_00/cpsb0001.dat
# ./data_00/cpsb0002.dat
# ./data_00/cpsb0003.dat
# ./data_00/cpsb0004.dat
# ./data_00/cpsb0005.dat
# ./data_00/cpsb0006.dat
# ./data_00/cpsb0007.dat
# ./data_00/cpsb0008.dat
# ./data_00/cpsb0009.dat
# ./data_00/cpsb0010.dat
# ./data_00/cpsb0011.dat
# ./data_00/cpsb0012.dat
# ./data_01/cpsb0101.dat
# ./data_01/cpsb0102.dat
# ./data_01/cpsb0103.dat
# ./data_01/cpsb0104.dat
# ./data_01/cpsb0105.dat
# ./data_01/cpsb0106.dat
# ./data_01/cpsb0107.dat
# ./data_01/cpsb0108.dat
# ./data_01/cpsb0109.dat
# ./data_01/cpsb0110.dat
# ./data_01/cpsb0111.dat
# ./data_01/cpsb0112.dat
# ./data_02/cpsb0201.dat
# ./data_02/cpsb0202.dat
# ./data_02/cpsb0203.dat
# ./data_02/cpsb0204.dat
# ./data_02/cpsb0205.dat
# ./data_02/cpsb0206.dat
# ./data_02/cpsb0207.dat
# ./data_02/cpsb0208.dat
# ./data_02/cpsb0209.dat
# ./data_02/cpsb0210.dat
# ./data_02/cpsb0211.dat
# ./data_02/cpsb0212.dat
# ./data_03/cpsb0301.dat
# ./data_03/cpsb0302.dat
# ./data_03/cpsb0303.dat
# ./data_03/cpsb0304.dat
# ...
